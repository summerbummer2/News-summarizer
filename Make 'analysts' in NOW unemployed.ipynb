# %% [markdown]
# # Welcome to Jupyter!

# %%
# !pip install --upgrade pip
# !pip install --upgrade ipython jupyter
# Out:
# Requirement already up-to-date: pip in /srv/conda/envs/notebook/lib/python3.6/site-packages (20.1.1)
# Requirement already up-to-date: ipython in /srv/conda/envs/notebook/lib/python3.6/site-packages (7.15.0)
# ...
#      |████████████████████████████████| 118 kB 8.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 54 kB 4.9 MB/s  eta 0:00:01
# ...

# %%
# !pip install nltk
# !pip install newspaper3k
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 4.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 82 kB 2.0 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 660 kB 19.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 4.2 MB/s  eta 0:00:01
# ...
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434676 sha256=173ca8d611079b37aa13cb87a5d2ec723a4971f4570adeb4035d218f222c82ce
#   Stored in directory: /home/jovyan/.cache/pip/wheels/de/5e/42/64abaeca668161c3e2cecc24f864a8fc421e3d07a104fc8a51
# Successfully built nltk
# ...
#      |████████████████████████████████| 211 kB 5.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.5 MB 9.2 MB/s eta 0:00:01     |██████████████▌                 | 2.5 MB 9.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 192 kB 31.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.4 MB 16.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 115 kB 33.7 MB/s eta 0:00:01
# ...

# %%
import nltk
from newspaper import Article
#article
url = 'https://www.straitstimes.com/asia/east-asia/china-unveils-security-law-for-hong-kong-citys-freedoms-in-doubt'
article = Article(url)

#NLP
article.download()
article.parse()
nltk.download('punkt')
article.nlp()
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#general information
article.authors

# %%
#article date
article.publish_date

# %%
#content
print(article.text)

# %%
print(article.summary)
# Out:
# BEIJING - China on Saturday (June 20) confirmed the setting up of an agency in Hong Kong to oversee the implementation of a national security law as the country’s top lawmaking body released details about the draft legislation.
# “The duties of the National Security Agency in Hong Kong are: to analyse and judge the situation of safeguarding the national security of (Hong Kong) and to provide opinions and suggestions on major strategies and important policies for maintaining the national security; to supervise, guide, coordinate, and support the implementation of the maintenance of the national security of (Hong Kong); collect and analyse national security intelligence information; handle crimes against national security according to law,” the draft said.
# But the agency will be separate from a dedicated unit the police will establish to deal with national security offences.
# ...

# %%
# Dehan pls delete this, later some unemployed clowns get offended
print("Lmao @ Nuggets of Weirdos, yall just got placed by a script")
# Out:
# Lmao @ Nuggets of Weirdos, yall just got placed by a script
